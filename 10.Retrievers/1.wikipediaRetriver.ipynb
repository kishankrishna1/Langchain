# %%
! pip install -qU langchain-community wikipedia
# Out:
# [notice] A new release of pip is available: 26.1.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from dotenv import load_dotenv
load_dotenv()

# %%
from langchain_community.retrievers import WikipediaRetriever
# Out:
# C:\Users\kisha\AppData\Local\Temp\ipykernel_1884\2879121110.py:1: DeprecationWarning: `langchain-community` is being sunset and is no longer actively maintained. See https://github.com/langchain-ai/langchain-community/issues/674 for details and migration guidance toward standalone integration packages.
#   from langchain_community.retrievers import WikipediaRetriever

# %%
# Initialize the retriever (optional: set language and top_k)
retriever = WikipediaRetriever(top_k_results=2, lang="en")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File c:\Users\kisha\miniconda3\envs\gen_ai_env\Lib\site-packages\langchain_community\utilities\wikipedia.py:39, in WikipediaAPIWrapper.validate_environment(cls, values)
#      38 try:
# ---> 39     import wikipedia
#      41     lang = values.get("lang", "en")
#
# ModuleNotFoundError: No module named 'wikipedia'
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# Cell In[3], line 2
#       1 # Initialize the retriever (optional: set language and top_k)
# ----> 2 retriever = WikipediaRetriever(top_k_results=2, lang="en")
#
# File c:\Users\kisha\miniconda3\envs\gen_ai_env\Lib\site-packages\langchain_core\load\serializable.py:118, in Serializable.__init__(self, *args, **kwargs)
#     116 def __init__(self, *args: Any, **kwargs: Any) -> None:
#     117     """"""  # noqa: D419  # Intentional blank docstring
# --> 118     super().__init__(*args, **kwargs)
#
#     [... skipping hidden 1 frame]
#
# File c:\Users\kisha\miniconda3\envs\gen_ai_env\Lib\site-packages\langchain_community\utilities\wikipedia.py:45, in WikipediaAPIWrapper.validate_environment(cls, values)
#      43     values["wiki_client"] = wikipedia
#      44 except ImportError:
# ---> 45     raise ImportError(
#      46         "Could not import wikipedia python package. "
#      47         "Please install it with `pip install wikipedia`."
#      48     )
#      49 return values
#
# ImportError: Could not import wikipedia python package. Please install it with `pip install wikipedia`.

# %%
# Define your query
query = "the geopolitical history of india and pakistan from the perspective of a chinese"

# Get relevant Wikipedia documents
docs = retriever.invoke(query)

# %%
docs

# %%
# Print retrieved content
for i, doc in enumerate(docs):
    print(f"\n--- Result {i+1} ---")
    print(f"Content:\n{doc.page_content}...")  # truncate for display
