# %%
! pip install langchain langchain-core langchain-community pydantic duckduckgo-search langchain_experimental
# Out:
# Requirement already satisfied: langchain in C:\Users\kisha\miniconda3\envs\gen_ai_env\Lib\site-packages (1.3.4)
# Requirement already satisfied: langchain-core in C:\Users\kisha\miniconda3\envs\gen_ai_env\Lib\site-packages (1.4.0)
# Requirement already satisfied: langchain-community in C:\Users\kisha\miniconda3\envs\gen_ai_env\Lib\site-packages (0.4.2)
# Requirement already satisfied: pydantic in C:\Users\kisha\miniconda3\envs\gen_ai_env\Lib\site-packages (2.13.4)
# Collecting duckduckgo-search
#   Downloading duckduckgo_search-8.1.1-py3-none-any.whl.metadata (16 kB)
# Collecting langchain_experimental
#   Downloading langchain_experimental-0.4.2-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: langgraph<1.3.0,>=1.2.4 in C:\Users\kisha\miniconda3\envs\gen_ai_env\Lib\site-packages (from langchain) (1.2.4)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in C:\Users\kisha\miniconda3\envs\gen_ai_env\Lib\site-packages (from langchain-core) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.14 in C:\Users\kisha\miniconda3\envs\gen_ai_env\Lib\site-packages (from langchain-core) (0.0.16)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in C:\Users\kisha\miniconda3\envs\gen_ai_env\Lib\site-packages (from langchain-core) (0.8.9)
# Requirement already satisfied: packaging>=23.2.0 in C:\Users\kisha\miniconda3\envs\gen_ai_env\Lib\site-packages (from langchain-core) (26.0)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in C:\Users\kisha\miniconda3\envs\gen_ai_env\Lib\site-packages (from langchain-core) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in C:\Users\kisha\miniconda3\envs\gen_ai_env\Lib\site-packages (from langchain-core) (9.1.4)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in C:\Users\kisha\miniconda3\envs\gen_ai_env\Lib\site-packages (from langchain-core) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in C:\Users\kisha\miniconda3\envs\gen_ai_env\Lib\site-packages (from langchain-core) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in C:\Users\kisha\miniconda3\envs\gen_ai_env\Lib\site-packages (from pydantic) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in C:\Users\kisha\miniconda3\envs\gen_ai_env\Lib\site-packages (from pydantic) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in C:\Users\kisha\miniconda3\envs\gen_ai_env\Lib\site-packages (from pydantic) (0.4.2)
# Requirement already satisfied: jsonpointer>=1.9 in C:\Users\kisha\miniconda3\envs\gen_ai_env\Lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core) (3.1.1)
# Requirement already satisfied: langgraph-checkpoint<5.0.0,>=4.1.0 in C:\Users\kisha\miniconda3\envs\gen_ai_env\Lib\site-packages (from langgraph<1.3.0,>=1.2.4->langchain) (4.1.1)
# Requirement already satisfied: langgraph-prebuilt<1.2.0,>=1.1.0 in C:\Users\kisha\miniconda3\envs\gen_ai_env\Lib\site-packages (from langgraph<1.3.0,>=1.2.4->langchain) (1.1.0)
# Requirement already satisfied: langgraph-sdk<0.5.0,>=0.4.2 in C:\Users\kisha\miniconda3\envs\gen_ai_env\Lib\site-packages (from langgraph<1.3.0,>=1.2.4->langchain) (0.4.2)
# Requirement already satisfied: xxhash>=3.5.0 in C:\Users\kisha\miniconda3\envs\gen_ai_env\Lib\site-packages (from langgraph<1.3.0,>=1.2.4->langchain) (3.7.0)
# Requirement already satisfied: ormsgpack>=1.12.0 in C:\Users\kisha\miniconda3\envs\gen_ai_env\Lib\site-packages (from langgraph-checkpoint<5.0.0,>=4.1.0->langgraph<1.3.0,>=1.2.4->langchain) (1.12.2)
# Requirement already satisfied: httpx>=0.25.2 in C:\Users\kisha\miniconda3\envs\gen_ai_env\Lib\site-packages (from langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.4->langchain) (0.28.1)
# Requirement already satisfied: orjson>=3.11.5 in C:\Users\kisha\miniconda3\envs\gen_ai_env\Lib\site-packages (from langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.4->langchain) (3.11.9)
# Requirement already satisfied: websockets<16,>=14 in C:\Users\kisha\miniconda3\envs\gen_ai_env\Lib\site-packages (from langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.4->langchain) (15.0.1)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in C:\Users\kisha\miniconda3\envs\gen_ai_env\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in C:\Users\kisha\miniconda3\envs\gen_ai_env\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (2.34.2)
# Requirement already satisfied: zstandard>=0.23.0 in C:\Users\kisha\miniconda3\envs\gen_ai_env\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (0.25.0)
# Requirement already satisfied: anyio in C:\Users\kisha\miniconda3\envs\gen_ai_env\Lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.4->langchain) (4.13.0)
# Requirement already satisfied: certifi in C:\Users\kisha\miniconda3\envs\gen_ai_env\Lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.4->langchain) (2026.5.20)
# Requirement already satisfied: httpcore==1.* in C:\Users\kisha\miniconda3\envs\gen_ai_env\Lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.4->langchain) (1.0.9)
# Requirement already satisfied: idna in C:\Users\kisha\miniconda3\envs\gen_ai_env\Lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.4->langchain) (3.18)
# Requirement already satisfied: h11>=0.16 in C:\Users\kisha\miniconda3\envs\gen_ai_env\Lib\site-packages (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.4->langchain) (0.16.0)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in C:\Users\kisha\miniconda3\envs\gen_ai_env\Lib\site-packages (from langchain-community) (3.14.0)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in C:\Users\kisha\miniconda3\envs\gen_ai_env\Lib\site-packages (from langchain-community) (0.4.3)
# Requirement already satisfied: langchain-classic<2.0.0,>=1.0.7 in C:\Users\kisha\miniconda3\envs\gen_ai_env\Lib\site-packages (from langchain-community) (1.0.7)
# Requirement already satisfied: numpy>=1.26.2 in C:\Users\kisha\miniconda3\envs\gen_ai_env\Lib\site-packages (from langchain-community) (2.4.6)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.10.1 in C:\Users\kisha\miniconda3\envs\gen_ai_env\Lib\site-packages (from langchain-community) (2.14.1)
# Requirement already satisfied: sqlalchemy<3.0.0,>=1.4.0 in C:\Users\kisha\miniconda3\envs\gen_ai_env\Lib\site-packages (from langchain-community) (2.0.50)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in C:\Users\kisha\miniconda3\envs\gen_ai_env\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.6.2)
# Requirement already satisfied: aiosignal>=1.4.0 in C:\Users\kisha\miniconda3\envs\gen_ai_env\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in C:\Users\kisha\miniconda3\envs\gen_ai_env\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (26.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in C:\Users\kisha\miniconda3\envs\gen_ai_env\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in C:\Users\kisha\miniconda3\envs\gen_ai_env\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in C:\Users\kisha\miniconda3\envs\gen_ai_env\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (0.5.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in C:\Users\kisha\miniconda3\envs\gen_ai_env\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.24.2)
# Requirement already satisfied: langchain-text-splitters<2.0.0,>=1.1.2 in C:\Users\kisha\miniconda3\envs\gen_ai_env\Lib\site-packages (from langchain-classic<2.0.0,>=1.0.7->langchain-community) (1.1.2)
# Requirement already satisfied: python-dotenv>=0.21.0 in C:\Users\kisha\miniconda3\envs\gen_ai_env\Lib\site-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain-community) (1.2.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in C:\Users\kisha\miniconda3\envs\gen_ai_env\Lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core) (3.4.7)
# Requirement already satisfied: urllib3<3,>=1.26 in C:\Users\kisha\miniconda3\envs\gen_ai_env\Lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core) (2.7.0)
# Requirement already satisfied: greenlet>=1 in C:\Users\kisha\miniconda3\envs\gen_ai_env\Lib\site-packages (from sqlalchemy<3.0.0,>=1.4.0->langchain-community) (3.5.1)
# Requirement already satisfied: click>=8.1.8 in C:\Users\kisha\miniconda3\envs\gen_ai_env\Lib\site-packages (from duckduckgo-search) (8.4.1)
# Collecting primp>=0.15.0 (from duckduckgo-search)
#   Downloading primp-1.3.1-cp310-abi3-win_amd64.whl.metadata (3.8 kB)
# Collecting lxml>=5.3.0 (from duckduckgo-search)
#   Downloading lxml-6.1.1-cp311-cp311-win_amd64.whl.metadata (3.6 kB)
# Requirement already satisfied: colorama in C:\Users\kisha\miniconda3\envs\gen_ai_env\Lib\site-packages (from click>=8.1.8->duckduckgo-search) (0.4.6)
# Downloading duckduckgo_search-8.1.1-py3-none-any.whl (18 kB)
# Downloading langchain_experimental-0.4.2-py3-none-any.whl (211 kB)
# Downloading lxml-6.1.1-cp311-cp311-win_amd64.whl (4.0 MB)
#    ---------------------------------------- 0.0/4.0 MB ? eta -:--:--
#    ----- ---------------------------------- 0.5/4.0 MB 2.8 MB/s eta 0:00:02
#    ------------- -------------------------- 1.3/4.0 MB 3.4 MB/s eta 0:00:01
#    ------------------ --------------------- 1.8/4.0 MB 3.1 MB/s eta 0:00:01
#    ------------------ --------------------- 1.8/4.0 MB 3.1 MB/s eta 0:00:01
#    ----------------------- ---------------- 2.4/4.0 MB 2.3 MB/s eta 0:00:01
#    ---------------------------- ----------- 2.9/4.0 MB 2.5 MB/s eta 0:00:01
#    ------------------------------------ --- 3.7/4.0 MB 2.4 MB/s eta 0:00:01
#    ---------------------------------------  3.9/4.0 MB 2.4 MB/s eta 0:00:01
#    ---------------------------------------  3.9/4.0 MB 2.4 MB/s eta 0:00:01
#    ---------------------------------------- 4.0/4.0 MB 1.9 MB/s  0:00:02
# Downloading primp-1.3.1-cp310-abi3-win_amd64.whl (4.7 MB)
#    ---------------------------------------- 0.0/4.7 MB ? eta -:--:--
#    -- ------------------------------------- 0.3/4.7 MB ? eta -:--:--
#    -------- ------------------------------- 1.0/4.7 MB 3.6 MB/s eta 0:00:02
#    --------------- ------------------------ 1.8/4.7 MB 3.7 MB/s eta 0:00:01
#    ---------------------- ----------------- 2.6/4.7 MB 4.0 MB/s eta 0:00:01
#    ----------------------------- ---------- 3.4/4.7 MB 3.8 MB/s eta 0:00:01
#    ----------------------------------- ---- 4.2/4.7 MB 3.8 MB/s eta 0:00:01
#    ---------------------------------------- 4.7/4.7 MB 3.8 MB/s  0:00:01
# Installing collected packages: primp, lxml, duckduckgo-search, langchain_experimental
#
#    ---------- ----------------------------- 1/4 [lxml]
#    ---------- ----------------------------- 1/4 [lxml]
#    -------------------- ------------------- 2/4 [duckduckgo-search]
#    ------------------------------ --------- 3/4 [langchain_experimental]
#    ------------------------------ --------- 3/4 [langchain_experimental]
#    ------------------------------ --------- 3/4 [langchain_experimental]
#    ------------------------------ --------- 3/4 [langchain_experimental]
#    ------------------------------ --------- 3/4 [langchain_experimental]
#    ------------------------------ --------- 3/4 [langchain_experimental]
#    ---------------------------------------- 4/4 [langchain_experimental]
#
# Successfully installed duckduckgo-search-8.1.1 langchain_experimental-0.4.2 lxml-6.1.1 primp-1.3.1

# %% [markdown]
# ## DuckDuckGo Search

# %%
from langchain_community.tools import DuckDuckGoSearchRun

search_tool = DuckDuckGoSearchRun()

results = search_tool.invoke('top news in india today')

print(results)
# Out:
# Top 5 news that shaped today: IndiGo cuts, Goa nightclub escape, Japan quake, Trump hints tariffs on rice, Invest UP’s Japan city plan, clear ... Top-India-news-today ... info@truescoopnews.com ... Copyright © 2025 TrueScoop News. ... News 24 is your stop for those who are inquisitive enough to keep abreast with the ... Today News Headlines in India: Stay Updated with DLSNews24 ... News 24 is your stop for those who are inquisitive enough to keep abreast with the ... Today News Headlines in India: Stay Updated with DLSNews24 Here are the top national and international news updates for today, covering key developments in politics, economy, diplomacy, and global events.

# %%
print(search_tool.name)
print(search_tool.description)
print(search_tool.args)
# Out:
# duckduckgo_search
# A wrapper around DuckDuckGo Search. Useful for when you need to answer questions about current events. Input should be a search query.
# {'query': {'description': 'search query to look up', 'title': 'Query', 'type': 'string'}}

# %% [markdown]
# ## Shell Tool

# %%
from langchain_community.tools import ShellTool

shell_tool = ShellTool()

results = shell_tool.invoke('whoami')

print(results)
# Out:
# Executing command:
#  whoami
# kishankrishna\kisha

# %% [markdown]
# # LangChain Built-in Tools — Quick Reference
#
# | Category | Tool | API Key Needed |
# |---|---|---|
# | Search | DuckDuckGo | ❌ Free |
# | Search | Google Serper | ✅ |
# | Search | Bing | ✅ |
# | Knowledge | Wikipedia | ❌ Free |
# | Knowledge | ArXiv | ❌ Free |
# | Knowledge | PubMed | ❌ Free |
# | Math | Wolfram Alpha | ✅ |
# | Weather | Open-Meteo | ❌ Free |
# | Weather | OpenWeatherMap | ✅ |
# | Code | PythonREPL | ❌ |
# | Web | Requests | ❌ |
# | Files | Read/Write/List | ❌ |
